# %%
import pandas as pd
from pathlib import Path

ROOT = Path("..")
marts_spark = ROOT / "data" / "processed" / "marts_spark"

pd.read_parquet(marts_spark / "agg_hour").shape, \
pd.read_parquet(marts_spark / "agg_dow").shape, \
pd.read_parquet(marts_spark / "agg_zone").shape
# Out:
# ((24, 4), (7, 4), (257, 6))

# %%
import pandas as pd
from pathlib import Path

ROOT = Path("..")
marts_spark = ROOT / "data" / "processed" / "marts_spark"

print("agg_hour:", pd.read_parquet(marts_spark / "agg_hour").shape)
print("agg_dow :", pd.read_parquet(marts_spark / "agg_dow").shape)
print("agg_zone:", pd.read_parquet(marts_spark / "agg_zone").shape)
print("pay_unknown_by_hour:", pd.read_parquet(marts_spark / "pay_unknown_by_hour").shape)
# Out:
# agg_hour: (24, 4)
# agg_dow : (7, 4)
# agg_zone: (257, 6)
# pay_unknown_by_hour: (24, 4)
